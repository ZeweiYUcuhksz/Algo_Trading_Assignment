# %%
from analy_alphas import *

start = 2013
end = 2023
alpha_name = 'Alphas101'
for year in range(start, end + 1):  # 2013-2023, including 2022 and 2023.
    list_assets, df_assets = get_hs300_stocks(f'{year}-01-01')
    generate_year_report(alpha_name, list_assets, year)
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_hs300 error_code:0
# query_hs300  error_msg:success
# logout success!
# 300
# Dropped 8.5% entries from factor data: 8.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# /Users/alanyu/Downloads/alphas-main/analy_alphas.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all['date'] = pd.to_datetime(df_all['date'])
# {'return_max': 4.4809504066822825, 'return_min': -0.7085413397422968, 'ic_mean': 0.01944425472314365, 'ic_std': 0.1282313971755444, 'ir': 0.1516341173178136}
# ...

# %%
ret[ret.avg_rank > 0.6]
# Out:
# year          2013      2014      2015      2016      2017      2018  \
# name
# alpha003  0.589286  0.545455  0.490566  0.907407  0.368421  0.254237
# alpha005  0.964286  0.854545  0.679245  0.833333  0.982456  0.949153
# alpha006  0.392857  0.272727  0.301887  0.296296  0.596491  0.406780
# alpha008  0.607143  0.945455  0.452830  0.777778  0.754386  0.728814
# alpha011  0.767857  0.963636  0.698113  0.981481  0.964912  0.864407
# alpha014  0.553571  0.436364  0.622642  0.351852  0.824561  0.813559
# alpha015  0.696429  0.818182  0.849057  0.759259  0.666667  0.745763
# alpha019       NaN       NaN       NaN       NaN       NaN  0.542373
# alpha024  1.000000  0.527273  0.754717  0.481481  0.543860  0.355932
# alpha025  0.232143  0.327273  0.320755  0.407407  0.561404  0.661017
# alpha026  0.821429  0.909091  0.924528  0.611111  0.877193  0.440678
# alpha028  0.803571  0.781818  0.188679  0.333333  0.614035  0.915254
# ...

# %%
from analy_alphas import *
ret = compare_factor('Alphas101', 2013, 2023)
ret
ret.to_csv('analysis/compare_result.csv')
# Out:
# year          2013      2014      2015      2016      2017      2018  \
# name
# alpha002  0.839286  0.454545  0.603774  0.722222  0.894737  0.508475
# alpha003  0.589286  0.545455  0.490566  0.907407  0.368421  0.254237
# alpha005  0.964286  0.854545  0.679245  0.833333  0.982456  0.949153
# alpha006  0.392857  0.272727  0.301887  0.296296  0.596491  0.406780
# alpha008  0.607143  0.945455  0.452830  0.777778  0.754386  0.728814
# ...            ...       ...       ...       ...       ...       ...
# alpha085  0.410714  0.890909  0.358491  0.222222  0.631579  0.830508
# alpha088  0.750000  0.690909  0.981132  0.944444  0.122807  0.169492
# alpha094  0.928571  0.927273  1.000000  0.870370  0.175439  0.067797
# alpha098  0.285714  0.418182  0.283019  0.240741  0.473684  0.474576
# alpha101  0.875000  0.981818  0.962264  0.444444  0.684211  0.559322
#
# year          2019      2020      2021      2022
# name
# alpha002  0.516667  0.450000  0.333333  0.533333
# ...
